# %%
import warnings

warnings.filterwarnings('ignore')

import requests
from bs4 import BeautifulSoup, NavigableString, Tag
import pandas as pd
import re

# %%
titleX = []
spX = []
mrpX = []
discountX = []
linkX = []
quantityX = []
categoryX = []
ratingX = []
rating_countX = []
review_countX = []

for page in range(1, 2):
    
    # target URL to scrap
    url = "https://www.naturesbasket.co.in/Online-grocery-shopping/dal?clk"
    
    # headers
    headers = {
        'User-Agent': "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/77.0.3865.90 Safari/537.36"
        }
    # send request to download the data
    response = requests.request("GET", url, headers=headers)

    # parse the downloaded data
    data = BeautifulSoup(response.text, 'html.parser')
    
    dal_data = data.find('div', attrs={'id': 'ctl00_ContentPlaceHolder1_divSearchData'})
    dal_data.find('div',class_='EkstopViewmore').decompose()
    
    for dal in dal_data:
        if isinstance(dal, NavigableString):
            continue
        if isinstance(dal, Tag):
#             pro_id = dal.div['pro-id']
#             dal_name_qty = dal.find('div', attrs={'class': "divOuterStructure_Search_16209 Search pro-id_20187"})
#             print(dal_name_qty)
            print(dal)
            print('\n\n')
# Out:
# <div align="left" class="divOuterStructure_Search_16209 Search pro-id_20187" pro-id="20187" style="float: left; height: 460px; z-index:0; position:relative;"> <div class="hide pro-id_20187" pro-id="20187" productbox="1" style="border-right: solid 1px #eee; height: 445px;"> <div class="divAddToMyListContainer" onclick="AddToMyListPopUpHtml(20187);"> <div class="divAddToMyListStar"> </div> <div class="divTextAddToMyList"> Add To Favourites </div> </div> <div align="left" class="pro-bucket" style=""> <div style="position:absolute; width: auto; height: 255px;top: 0px;background-image:url(https://d1z88p83zuviay.cloudfront.net/Images/ekloading32x32.gif);background-position: center center;background-repeat:no-repeat;z-index:0"></div> <div align="left" class="pro-buck-img" style=""> <a href="https://www.naturesbasket.co.in/Products/Toor-Dal---Tata/20187_0_0_0" style="text-decoration:none"> <img alt="Toor Dal - Tata" src="https://d1z88p83zuviay.cloudfront.net/Images/no-images425x425.jpg" styl
# ...
